# %%
import numpy as np
import pandas as pd
import keras
import tensorflow as tf

from keras.preprocessing import image
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.models import Model, Sequential
from keras.layers import (Activation, Input, MaxPooling2D, BatchNormalization, Conv2D, Conv2DTranspose, concatenate)
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam

from IPython.display import clear_output

import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# Использовался датасет https://www.kaggle.com/carlolepelaars/camvid

# %%
np.random.seed(42)

# %%
class_dict = pd.read_csv('C:/Ангелина/Data Sience/4 четверть/Нейронные сети/6/CamVid/class_dict.csv')

path_train = 'C:/Ангелина/Data Sience/4 четверть/Нейронные сети/6/CamVid/train/'
path_train_labels = 'C:/Ангелина/Data Sience/4 четверть/Нейронные сети/6/CamVid/train_labels/'
path_test = 'C:/Ангелина/Data Sience/4 четверть/Нейронные сети/6/CamVid/test/'
path_test_labels = 'C:/Ангелина/Data Sience/4 четверть/Нейронные сети/6/CamVid/test_labels/'
path_val = 'C:/Ангелина/Data Sience/4 четверть/Нейронные сети/6/CamVid/val/'
path_val_labels = 'C:/Ангелина/Data Sience/4 четверть/Нейронные сети/6/CamVid/val_labels/'

# %%
train_images_paths = list(Path(path_train).iterdir())

# %%
single_image = tf.keras.preprocessing.image.load_img(train_images_paths[2]).size
single_image
# Out:
# (960, 720)

# %%
train_imgs_paths = list(sorted(Path(path_train).iterdir()))
train_masks_paths = list(sorted(Path(path_train_labels).iterdir()))
test_imgs_paths = list(sorted(Path(path_test).iterdir()))
test_masks_paths = list(sorted(Path(path_test_labels).iterdir()))
val_imgs_paths = list(sorted(Path(path_val).iterdir()))
val_masks_paths = list(sorted(Path(path_val_labels).iterdir()))

# %%
#image_size = (120, 180)
image_size = (128, 192)

# %%
# %%time

train_images = []
train_masks = []

for i_img, i_mask in zip(train_imgs_paths, train_masks_paths):
  train_images.append(tf.keras.preprocessing.image.load_img(i_img, target_size=image_size))
  train_masks.append(tf.keras.preprocessing.image.load_img(i_mask, target_size=image_size))
# Out:
# Wall time: 15.3 s

# %%
# %%time

test_images = []
test_masks = []

for i_img, i_mask in zip(test_imgs_paths, test_masks_paths):
  test_images.append(tf.keras.preprocessing.image.load_img(i_img, target_size=image_size))
  test_masks.append(tf.keras.preprocessing.image.load_img(i_mask, target_size=image_size))
# Out:
# Wall time: 9.76 s

# %%
# %%time

val_images = []
val_masks = []

for i_img, i_mask in zip(val_imgs_paths, val_masks_paths):
  val_images.append(tf.keras.preprocessing.image.load_img(i_img, target_size=image_size))
  val_masks.append(tf.keras.preprocessing.image.load_img(i_mask, target_size=image_size))
# Out:
# Wall time: 4.16 s

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 12))
ax[0].imshow(train_images[15].convert('RGBA'))
ax[1].imshow(train_masks[15].convert('RGBA'))

# %% [markdown]
# Создаём обучающую выборку

# %%
X_train = []

for img in train_images:
  x = tf.keras.preprocessing.image.img_to_array(img)
  X_train.append(x)

X_train = np.array(X_train)
print(X_train.shape)
# Out:
# (369, 128, 192, 3)

# %%
X_test = []

for img in test_images:
  x = tf.keras.preprocessing.image.img_to_array(img)
  X_test.append(x)

X_test = np.array(X_test)
print(X_test.shape)
# Out:
# (232, 128, 192, 3)

# %%
X_val = []

for img in val_images:
  x = tf.keras.preprocessing.image.img_to_array(img)
  X_val.append(x)

X_val = np.array(X_val)
print(X_val.shape)
# Out:
# (100, 128, 192, 3)

# %% [markdown]
# разметка

# %%
class_dict
# Out:
#                  name    r    g    b
# 0              Animal   64  128   64
# 1             Archway  192    0  128
# 2           Bicyclist    0  128  192
# 3              Bridge    0  128   64
# 4            Building  128    0    0
# 5                 Car   64    0  128
# 6     CartLuggagePram   64    0  192
# 7               Child  192  128   64
# 8         Column_Pole  192  192  128
# 9               Fence   64   64  128
# 10       LaneMkgsDriv  128    0  192
# 11    LaneMkgsNonDriv  192    0   64
# 12          Misc_Text  128  128   64
# 13  MotorcycleScooter  192    0  192
# 14        OtherMoving  128   64   64
# 15       ParkingBlock   64  192  128
# 16         Pedestrian   64   64    0
# 17               Road  128   64  128
# 18       RoadShoulder  128  128  192
# 19           Sidewalk    0    0  192
# 20         SignSymbol  192  128  128
# 21                Sky  128  128  128
# 22     SUVPickupTruck   64  128  192
# 23        TrafficCone    0    0   64
# 24       TrafficLight    0   64   64
# 25              Train  192   64  128
# 26               Tree  128  128    0
# 27          Truck_Bus  192  128  192
# 28             Tunnel   64    0   64
# 29     VegetationMisc  192  192    0
# 30               Void    0    0    0
# 31               Wall   64  192    0

# %% [markdown]
# конвертер в one-hot_encoding для выходных примеров

# %%
arr_col = []

for r, g, b in zip(class_dict['r'], class_dict['g'], class_dict['b']):
  arr_col.append([r, g, b])

# %%
def Color2index(y, arr_col=arr_col):

  y_ind = np.zeros((y.shape[0], y.shape[1]))
  y_cat = np.zeros((y.shape[0], y.shape[1], len(arr_col)))
  i = 1
  for i_color in arr_col:
    ind_i = np.where(
        (y[..., 0] == i_color[0])
        & (y[..., 1] == i_color[1])
        & (y[..., 2] == i_color[2])        
    )
    y_ind[ind_i[0], ind_i[1]] = i
    y_cat[ind_i[0], ind_i[1], i-1] = 1
    i += 1
  
  return y_cat, y_ind

# %%
cat_yi, ind_yi = Color2index(tf.keras.preprocessing.image.img_to_array(train_masks[3]))
plt.imshow(ind_yi)
plt.show()

# %%
ind_yi
# Out:
# array([[22., 22., 22., ..., 27., 27., 27.],
#        [22., 22., 22., ..., 27., 27., 27.],
#        [22., 22., 22., ..., 27., 27., 27.],
#        ...,
#        [20., 20., 20., ..., 31., 31., 31.],
#        [20., 20., 20., ..., 31., 31., 31.],
#        [20., 20., 20., ..., 31., 31., 31.]])

# %%
plt.imshow(cat_yi[..., 17])
plt.show()

# %%
cat_yi.shape
# Out:
# (128, 192, 32)

# %% [markdown]
# Сегментированная картинка в One hot encoding (разметка на 32 класса)

# %%
y_train = []

for mask in train_masks:
  y_cat, _ = Color2index(tf.keras.preprocessing.image.img_to_array(mask))
  y_train.append(y_cat)

y_train = np.array(y_train)

# %%
n = 0 
plt.imshow(train_masks[n].convert('RGBA'))
plt.show()
img = y_train[n][..., 22]

plt.imshow(img)
plt.show()

# %%
y_test = []

for mask in test_masks:
  y_cat, _ = Color2index(tf.keras.preprocessing.image.img_to_array(mask))
  y_test.append(y_cat)

y_test = np.array(y_test)

# %%
y_val = []

for mask in val_masks:
  y_cat, _ = Color2index(tf.keras.preprocessing.image.img_to_array(mask))
  y_val.append(y_cat)

y_val = np.array(y_val)

# %%
print(f'{X_train.shape}, \n{y_train.shape}')
# Out:
# (369, 128, 192, 3),
# (369, 128, 192, 32)

# %%
def unet_pre_train(num_classes=32, input_shape=(128, 192, 3)):
  pre_trained_model = VGG16(input_shape=input_shape, include_top=False, weights='imagenet')

  for layer in pre_trained_model.layers[:-5]:
    layer.trainable = False

    x = pre_trained_model.layers[13].output
    block_4_out = pre_trained_model.layers[10].output
    block_3_out = pre_trained_model.layers[6].output
    block_2_out = pre_trained_model.layers[3].output
    img_input = pre_trained_model.input
    print(block_4_out)
    print(block_3_out)
    print(block_2_out)

    # UP 1

    # добавили перенос из VGG16
    x = concatenate([x, block_4_out])
    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)


    #UP 2
    x = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # добавили перенос из VGG16
    x = concatenate([x, block_3_out])
    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2DTranspose(256, (2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)


    #UP 3
    x = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # добавили перенос из VGG16
    x = concatenate([x, block_2_out])
    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2DTranspose(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)


    #UP 4
    x = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_classes, (3, 3), activation='softmax', padding='same')(x)

    model = Model(img_input, x)
    return model

# %%
model = unet_pre_train(32, (128, 192, 3))

plot_model(model, to_file='model.png', show_shapes=True)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 16, 24, 256), dtype=tf.float32, name=None), name='block3_pool/MaxPool:0', description="created by layer 'block3_pool'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 32, 48, 128), dtype=tf.float32, name=None), name='block2_pool/MaxPool:0', description="created by layer 'block2_pool'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 64, 96, 64), dtype=tf.float32, name=None), name='block1_pool/MaxPool:0', description="created by layer 'block1_pool'")
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
import keras.backend as K

def dice_coef(y_true, y_pred):
  return (2. * K.sum(y_true * y_pred)) / (K.sum(y_true) + K.sum(y_pred))

# %%
model.compile(optimizer=Adam(),
              loss='categorical_crossentropy',
              metrics=[dice_coef])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 192, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 128, 192, 64  1792        ['input_2[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 128, 192, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 64, 96, 64)   0           ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 64, 96, 128)  73856       ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 64, 96, 128)  147584      ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 32, 48, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 32, 48, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 32, 48, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 32, 48, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 16, 24, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 16, 24, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 16, 24, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 16, 24, 512)  2359808     ['block4_conv2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 16, 24, 768)  0           ['block4_conv3[0][0]',
#                                                                   'block3_pool[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 24, 256)  1769728     ['concatenate_3[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 24, 256)  1024       ['conv2d_7[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 16, 24, 256)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 24, 256)  590080      ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 16, 24, 256)  1024       ['conv2d_8[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 16, 24, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 32, 48, 256)  262400     ['activation_12[0][0]']
#  spose)
#
#  batch_normalization_13 (BatchN  (None, 32, 48, 256)  1024       ['conv2d_transpose_5[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 48, 256)  0           ['batch_normalization_13[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 32, 48, 384)  0           ['activation_13[0][0]',
#                                                                   'block2_pool[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 48, 256)  884992      ['concatenate_4[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 48, 256)  1024       ['conv2d_9[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 32, 48, 256)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 32, 48, 256)  262400     ['activation_14[0][0]']
#  spose)
#
#  batch_normalization_15 (BatchN  (None, 32, 48, 256)  1024       ['conv2d_transpose_6[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 48, 256)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 64, 96, 128)  131200     ['activation_15[0][0]']
#  spose)
#
#  batch_normalization_16 (BatchN  (None, 64, 96, 128)  512        ['conv2d_transpose_7[0][0]']
#  ormalization)
#  activation_16 (Activation)     (None, 64, 96, 128)  0           ['batch_normalization_16[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 64, 96, 192)  0           ['activation_16[0][0]',
#                                                                   'block1_pool[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 96, 128)  221312      ['concatenate_5[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 64, 96, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 64, 96, 128)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_transpose_8 (Conv2DTran  (None, 64, 96, 128)  147584     ['activation_17[0][0]']
#  spose)
#
#  batch_normalization_18 (BatchN  (None, 64, 96, 128)  512        ['conv2d_transpose_8[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 64, 96, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 128, 192, 64  32832      ['activation_18[0][0]']
#  spose)                         )
#
#  batch_normalization_19 (BatchN  (None, 128, 192, 64  256        ['conv2d_transpose_9[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 128, 192, 64  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 128, 192, 64  36928       ['activation_19[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 128, 192, 64  256        ['conv2d_11[0][0]']
#  ormalization)                  )
#
#  activation_20 (Activation)     (None, 128, 192, 64  0           ['batch_normalization_20[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 128, 192, 64  36928       ['activation_20[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 128, 192, 64  256        ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  activation_21 (Activation)     (None, 128, 192, 64  0           ['batch_normalization_21[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 128, 192, 32  18464       ['activation_21[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 12,037,536
# Trainable params: 12,033,824
# Non-trainable params: 3,712
# __________________________________________________________________________________________________

# %%
sample_image = X_test[1]
sample_mask = y_test[1]

# %%
def show_predictions(model):
  pred_mask = model.predict(sample_image[None])[..., 16]
  print(pred_mask.shape)

  fig, ax = plt.subplots(1, 3, figsize=(15, 8))

  ax[0].imshow(sample_image / 255.0)
  ax[1].imshow(sample_mask[..., 16])
  ax[2].imshow(np.squeeze(pred_mask, axis=0))
  plt.show()

class DisplayCallback(keras.callbacks.Callback):
  def __init__(self, patience=1):
    super().__init__()
    self.patience = patience

  def on_train_begin(self, logs=None):
    self.wait = 0
  
  def on_epoch_end(self, epoch, logs=None):
    self.wait += 1
    if self.wait >= self.patience:
      clear_output(wait=True)
      show_predictions(self.model)
      print(f'\nSample Prediction after epoch {epoch+1}')
      self.wait = 0

# %%
show_predictions(model)
# Out:
# 1/1 [==============================] - 1s 735ms/step
# (1, 128, 192)

# %%
from keras import callbacks
history = model.fit(preprocess_input(X_train), y_train,
                    epochs=20,
                    batch_size=10,
                    validation_data=(preprocess_input(X_test), y_test),
                    callbacks=[DisplayCallback(patience=5)])
# Out:
# 1/1 [==============================] - 0s 328ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1, 128, 192)
# Sample Prediction after epoch 20
# 37/37 [==============================] - 424s 12s/step - loss: 0.3336 - dice_coef: 0.8482 - val_loss: 0.6579 - val_dice_coef: 0.7865

# %%
plt.plot(history.history['val_dice_coef'], label='test')
plt.plot(history.history['dice_coef'], label='train')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('dice_coef')
plt.show()

# %% [markdown]
# Тестируем на валидационных данных

# %%
pred = model.predict(X_val)
print(pred.shape)
# Out:
# 4/4 [==============================] - 25s 6s/step
# (100, 128, 192, 32)

# %%
n = 3
class_ = 17
plt.imshow(val_images[n].convert('RGBA'))
plt.title('входной кадр')
plt.show()
plt.imshow(val_masks[n].convert('RGBA')) 
plt.title('целевая разметка')
plt.show()
img = y_val[n][..., class_]
plt.imshow(img)
plt.title('целевая разметка класс: ' + str(class_))
plt.show()
img = pred[n][..., class_]
plt.imshow(img)
plt.title('предиктивная разметка класс: ' + str(class_))
plt.show()

# %% [markdown]
# Задача решена на наборе данных CamVid (Cambridge-Driving Labeled Video Database) для 32 классов с помощью нейронной сети u-net, используя обученный энкодер из VGG16.
